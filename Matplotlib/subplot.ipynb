# %%
# We use subplot when we need to show multiple charts in a single frame

'''  
Suppose we need to see 
 
department wise salary
department wise total employee
department wise satisfaction score
department wise absences

at that time instead of creating a diff chart in diff frame 
we can simple create a multiple charts in a singlr frame
'''

# %%
# first do it then visualize 
''' 
emp_dep = df.groupby('Department').agg(
total_sal = ('salary', 'sum'),
total_emp = ('emp','count'),
emp_satis = ('satis_score', 'sum'),
total_abs = ('absences', 'sum')
).reset_index()
emp_dep
'''

# %%
# Now lets visualize

'''

fig , axes = plt.subplots(2, 2, figsize=(10, 12)) -> axes will hold (2,2)  and fig will hold (10,12)
plt.suptitle("Department vs Others")
plt.subplots_adjust(hspace=0.5)

ax1 = axes[0,0]
ax1.bar(emp_dep['department'], emp_dep['total_salary'])
ax1.set_title("Total salary by Department")
ax1.set_xlabel("Department")
ax1.set_ylabel("Salary")
ax1.tick_params(axis='x', rotation=15)

similary do for others go for ax2 = axes[0,1] ...... [1,0].......... [1,1]


'''
