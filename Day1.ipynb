# %% [markdown]
# In normal list while adding list, its concat

# %%
#
a = [1,2,3,4]
b = [1,2,3,4]
c = a + b
print(c)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %% [markdown]
# Lets add list using numpy
# 1D ARRAY

# %%
import numpy as np
a = np.array([1,2,3,4])
b = np.array([1,2,3,4])

print(type(a))
print(type(b))


print(a+b)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [2 4 6 8]

# %% [markdown]
# 2D ARRAY

# %%
two_d_array = np.array([
   [1,2,3],
   [1,2,3],
   [1,2,3]
)

print(two_d_array)
# Out:
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]
